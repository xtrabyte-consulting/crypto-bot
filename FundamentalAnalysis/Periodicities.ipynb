# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from FrequencyAnalysis import PeriodAnalysis
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
eth_min = pd.read_csv('../data/ETH-USD_60_prices.csv')
eth = pd.read_csv('../data/ETH-USD_3600_prices.csv')
pa = PeriodAnalysis(eth['close'])

# %%
print(eth.info())
eth.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65989 entries, 0 to 65988
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   low     65989 non-null  float64
#  1   high    65989 non-null  float64
#  2   open    65989 non-null  float64
#  3   close   65989 non-null  float64
#  4   volume  65989 non-null  float64
# dtypes: float64(5)
# memory usage: 2.5 MB
# None
#                 low          high          open         close         volume
# count  65989.000000  65989.000000  65989.000000  65989.000000   65989.000000
# mean    1000.720289   1013.553077   1007.393710   1007.429755    7435.441693
# std     1092.184758   1105.934290   1099.329763   1099.337048    9660.891328
# min        0.100000      6.230000      5.980000      5.990000       0.000171
# 25%      177.000000    179.390000    178.110000    178.130000    2137.072771
# 50%      411.810000    416.380000    414.160000    414.160000    4437.676558
# ...

# %%
sns.set_style('darkgrid')
sns.set_context('talk')
plt.figure(figsize=(12, 8))
sns.lineplot(eth['close'])
# Out:
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(6, 4))
sns.lineplot(eth['close'].iloc[54000:])
# Out:
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fourier = pa.scale_and_transform()
pa.display_transform_statistics()
pa.plot_transformed()
# Out:
# Number of observations: 65989
# Frequency range: -0.4999924229795875 - 0.4999924229795875
# Amplitude mean: 2.904095208725442
# Amplitude standard deviation: 78.82362958571697
# Amplitude max: 13645.121976853427
# Amplitude min: 0.006012320279022317
# Amplitude median: 0.5857644160479063
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
pa.plot_transformed(6, 300)
# Out:
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/envs/crypto_rnns/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
pa = PeriodAnalysis(eth['close'].iloc[54000])
pa.
